# %%
from urlpath import URL
from pprint import pprint
import time
from datetime import datetime, date
from datetime import time as dt_time

from IPython.display import clear_output

from src.params import StationID
from src.nws import NWSClient, parse_product_text

# url = URL("https://api.weather.gov/products/1eae2f39-8187-42ad-ab00-1f212b40a93a")
# url = URL("https://api.weather.gov/products/9c5a3929-9e59-46df-b406-a1aae6ca946c")

station = StationID.HOU
url = URL(f"https://forecast.weather.gov/product.php?site=DTX&issuedby={station}&product=CLI&format=CI&version=1&glossary=0")
client = NWSClient()
while True:
    print(f"Query Time: {time.ctime()}")
    report = client.get_cli_data(station, version=1)

    print(f"Summary Date {report.summary_date.strftime('%Y-%m-%d')}")
    if report.summary_date == date.today() and (report.valid_time is not None) and (report.valid_time.time() >= dt_time(12, 0)):
        print("UPDATED TODAY")
    pprint(report.without_raw_text())
    print(report.raw_text)

    clear_output(wait=True)
    time.sleep(15)
# Out:
# Query Time: Wed Nov 20 16:03:53 2024
# Summary Date 2024-11-19
# CLI(station=<StationID.MDW: 'MDW'>,
#     issuance_time=datetime.datetime(2024, 11, 20, 0, 34, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#     issuing_office='LOT',
#     summary_date=datetime.date(2024, 11, 19),
#     raw_text='...',
#     is_afternoon_report=False,
#     max_temp=65,
#     max_temp_time=datetime.datetime(2024, 11, 19, 14, 46, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#     min_temp=47,
#     min_temp_time=datetime.datetime(2024, 11, 19, 23, 34, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#     avg_temp=56,
#     valid_time=None,
#     is_correction=False)
# 782
# CDUS43 KLOT 200634
# CLIMDW
#
# CLIMATE REPORT
# NATIONAL WEATHER SERVICE CHICAGO IL
# 1234 AM CST WED NOV 20 2024
#
# ...................................
#
# ...THE CHICAGO-MIDWAY CLIMATE SUMMARY FOR NOVEMBER 19 2024...
#
# CLIMATE NORMAL PERIOD: 1991 TO 2020
# CLIMATE RECORD PERIOD: 1928 TO 2024
#
#
# WEATHER ITEM   OBSERVED TIME   RECORD YEAR NORMAL DEPARTURE LAST
#                 VALUE   (LST)  VALUE       VALUE  FROM      YEAR
#                                                   NORMAL
# ...................................................................
# TEMPERATURE (F)
#  YESTERDAY
#   MAXIMUM         65   2:46 PM  77    1930  47     18       54
#   MINIMUM         47  11:34 PM  16    2022  34     13       36
#   AVERAGE         56                        40     16       45
#
# PRECIPITATION (IN)
#   YESTERDAY        0.06          0.74 1941   0.08  -0.02     0.00
#   MONTH TO DATE    2.49                      1.54   0.95     0.02
#   SINCE SEP 1      5.60                      7.79  -2.19     6.37
#   SINCE JAN 1     35.07                     31.82   3.25    31.98
#
# DEGREE DAYS
#  HEATING
#   YESTERDAY        9                        24    -15       20
#   MONTH TO DATE  216                       394   -178      299
#   SINCE SEP 1    398                       785   -387      627
#   SINCE JUL 1    398                       789   -391      628
#
#  COOLING
#   YESTERDAY        0                         0      0        0
#   MONTH TO DATE    2                         0      2        0
#   SINCE SEP 1    261                       156    105      187
#   SINCE JAN 1   1384                      1112    272     1149
# ...................................................................
#
#
# WIND (MPH)
#   HIGHEST WIND SPEED    28   HIGHEST WIND DIRECTION    SW (220)
#   HIGHEST GUST SPEED    40   HIGHEST GUST DIRECTION    SW (220)
#   AVERAGE WIND SPEED    15.0
#
#
# SKY COVER
#   AVERAGE SKY COVER 0.6
#
#
# WEATHER CONDITIONS
# THE FOLLOWING WEATHER WAS RECORDED YESTERDAY.
#   LIGHT RAIN
#   FOG
#
#
# RELATIVE HUMIDITY (PERCENT)
#  HIGHEST    87           3:00 AM
#  LOWEST     56           4:00 PM
#  AVERAGE    72
#
# ..........................................................
#
#
# THE CHICAGO-MIDWAY CLIMATE NORMALS FOR TODAY
#                          NORMAL    RECORD    YEAR
#  MAXIMUM TEMPERATURE (F)   47        69      1930
#  MINIMUM TEMPERATURE (F)   33        13      2022
#
#
# SUNRISE AND SUNSET
# NOVEMBER 20 2024......SUNRISE   6:47 AM CST   SUNSET   4:26 PM CST
# NOVEMBER 21 2024......SUNRISE   6:48 AM CST   SUNSET   4:25 PM CST
#
#
# -  INDICATES NEGATIVE NUMBERS.
# R  INDICATES RECORD WAS SET OR TIED.
# MM INDICATES DATA IS MISSING.
# T  INDICATES TRACE AMOUNT.
#
#
#
#
# $$
