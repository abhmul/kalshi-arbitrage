# %%
from datetime import datetime, timedelta, date
from dateutil.relativedelta import relativedelta
from pprint import pprint
import json
import requests
import numpy as np
import pandas as pd

from src.params import *
from src.nws import NWSClient
from src.nws import (
    fahrenheit_to_celsius,
    celsius_to_fahrenheit,
    load_clis,
    load_one_minutes,
    end_of_day,
    start_of_day,
    in_date_range,
    CLI
)

# %%
stations = [station for station in StationID if station != StationID.PIR]

clis = [cli  for station in stations for cli in load_clis(station)]
clis = sorted(clis, key=lambda cli: (cli.station.value, cli.summary_date, cli.issuance_time))

pprint([cli.without_raw_text()  for cli in sorted(clis, key=lambda cli: (cli.summary_date, cli.issuance_time, cli.station.value))])
# Out:
# [CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 22, 1, 33, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 21),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=82,
#      max_temp_time=datetime.datetime(2024, 10, 21, 16, 6, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=53,
#      min_temp_time=datetime.datetime(2024, 10, 21, 4, 7, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=68,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 22, 4, 22, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 21),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=86,
#      max_temp_time=datetime.datetime(2024, 10, 21, 14, 45, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=74,
#      min_temp_time=datetime.datetime(2024, 10, 21, 7, 5, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=80,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 22, 16, 22, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 22),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=86,
#      max_temp_time=datetime.datetime(2024, 10, 22, 13, 47, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=76,
#      min_temp_time=datetime.datetime(2024, 10, 22, 5, 41, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=81,
#      valid_time=datetime.datetime(2024, 10, 22, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 22, 16, 36, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 22),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=74,
#      max_temp_time=datetime.datetime(2024, 10, 22, 14, 59, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=55,
#      min_temp_time=datetime.datetime(2024, 10, 22, 6, 18, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=65,
#      valid_time=datetime.datetime(2024, 10, 22, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 23, 1, 34, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 22),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=75,
#      max_temp_time=datetime.datetime(2024, 10, 22, 15, 45, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=55,
#      min_temp_time=datetime.datetime(2024, 10, 22, 6, 18, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=65,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 23, 4, 22, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 22),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=86,
#      max_temp_time=datetime.datetime(2024, 10, 22, 13, 47, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=76,
#      min_temp_time=datetime.datetime(2024, 10, 22, 5, 41, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=81,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 23, 16, 40, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 23),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=87,
#      max_temp_time=datetime.datetime(2024, 10, 23, 13, 26, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=75,
#      min_temp_time=datetime.datetime(2024, 10, 23, 7, 3, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=81,
#      valid_time=datetime.datetime(2024, 10, 23, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 23, 16, 36, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 23),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=65,
#      max_temp_time=datetime.datetime(2024, 10, 23, 14, 47, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=58,
#      min_temp_time=datetime.datetime(2024, 10, 23, 6, 37, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=62,
#      valid_time=datetime.datetime(2024, 10, 23, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 24, 2, 22, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 23),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=75,
#      max_temp_time=datetime.datetime(2024, 10, 23, 12, 32, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=59,
#      min_temp_time=datetime.datetime(2024, 10, 23, 4, 41, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=67,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 24, 1, 37, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 23),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=65,
#      max_temp_time=None,
#      min_temp=46,
#      min_temp_time=None,
#      avg_temp=56,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 24, 4, 24, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 23),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=87,
#      max_temp_time=datetime.datetime(2024, 10, 23, 13, 26, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=75,
#      min_temp_time=datetime.datetime(2024, 10, 23, 23, 59, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=81,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 24, 16, 21, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 24),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=84,
#      max_temp_time=datetime.datetime(2024, 10, 24, 14, 22, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=73,
#      min_temp_time=datetime.datetime(2024, 10, 24, 5, 31, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=79,
#      valid_time=datetime.datetime(2024, 10, 24, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 24, 16, 52, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 24),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=69,
#      max_temp_time=datetime.datetime(2024, 10, 24, 14, 18, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=60,
#      min_temp_time=datetime.datetime(2024, 10, 24, 8, 39, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=65,
#      valid_time=datetime.datetime(2024, 10, 24, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 24, 16, 32, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 24),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=65,
#      max_temp_time=datetime.datetime(2024, 10, 24, 14, 26, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=42,
#      min_temp_time=datetime.datetime(2024, 10, 24, 5, 58, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=54,
#      valid_time=datetime.datetime(2024, 10, 24, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 25, 2, 16, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 24),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=69,
#      max_temp_time=datetime.datetime(2024, 10, 24, 14, 18, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=53,
#      min_temp_time=datetime.datetime(2024, 10, 24, 23, 59, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=61,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 25, 1, 35, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 24),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=65,
#      max_temp_time=datetime.datetime(2024, 10, 24, 14, 26, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=42,
#      min_temp_time=datetime.datetime(2024, 10, 24, 5, 58, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=54,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 25, 4, 25, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 24),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=84,
#      max_temp_time=datetime.datetime(2024, 10, 24, 14, 22, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=73,
#      min_temp_time=datetime.datetime(2024, 10, 24, 5, 31, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=79,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 25, 16, 33, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 25),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=62,
#      max_temp_time=datetime.datetime(2024, 10, 25, 15, 31, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=46,
#      min_temp_time=datetime.datetime(2024, 10, 25, 6, 48, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=54,
#      valid_time=datetime.datetime(2024, 10, 25, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 25, 16, 38, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 25),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=85,
#      max_temp_time=datetime.datetime(2024, 10, 25, 13, 40, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=73,
#      min_temp_time=datetime.datetime(2024, 10, 25, 5, 23, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=79,
#      valid_time=datetime.datetime(2024, 10, 25, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 25, 16, 40, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 25),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=68,
#      max_temp_time=datetime.datetime(2024, 10, 25, 14, 8, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=50,
#      min_temp_time=datetime.datetime(2024, 10, 25, 2, 6, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=59,
#      valid_time=datetime.datetime(2024, 10, 25, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 10, 25, 17, 47, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 10, 25),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=66,
#      max_temp_time=datetime.datetime(2024, 10, 25, 15, 57, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=44,
#      min_temp_time=datetime.datetime(2024, 10, 25, 6, 39, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=55,
#      valid_time=datetime.datetime(2024, 10, 25, 17, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 10, 26, 1, 48, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 10, 25),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=66,
#      max_temp_time=datetime.datetime(2024, 10, 25, 16, 12, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=44,
#      min_temp_time=datetime.datetime(2024, 10, 25, 6, 39, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=55,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 26, 2, 18, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 25),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=62,
#      max_temp_time=datetime.datetime(2024, 10, 25, 16, 4, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=46,
#      min_temp_time=datetime.datetime(2024, 10, 25, 6, 48, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=54,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 26, 1, 41, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 25),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=68,
#      max_temp_time=datetime.datetime(2024, 10, 25, 14, 8, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=48,
#      min_temp_time=datetime.datetime(2024, 10, 25, 23, 45, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=58,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 26, 4, 21, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 25),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=85,
#      max_temp_time=datetime.datetime(2024, 10, 25, 13, 40, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=73,
#      min_temp_time=datetime.datetime(2024, 10, 25, 5, 23, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=79,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 26, 16, 21, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 26),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=86,
#      max_temp_time=datetime.datetime(2024, 10, 26, 12, 30, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=74,
#      min_temp_time=datetime.datetime(2024, 10, 26, 7, 2, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=80,
#      valid_time=datetime.datetime(2024, 10, 26, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 26, 16, 32, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 26),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=64,
#      max_temp_time=datetime.datetime(2024, 10, 26, 13, 47, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=54,
#      min_temp_time=datetime.datetime(2024, 10, 26, 6, 50, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=59,
#      valid_time=datetime.datetime(2024, 10, 26, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.HOU: 'HOU'>,
#      issuance_time=datetime.datetime(2024, 10, 26, 16, 7, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='HGX',
#      summary_date=datetime.date(2024, 10, 26),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=90,
#      max_temp_time=datetime.datetime(2024, 10, 26, 14, 22, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=69,
#      min_temp_time=datetime.datetime(2024, 10, 26, 6, 24, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=80,
#      valid_time=datetime.datetime(2024, 10, 26, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 26, 16, 33, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 26),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=59,
#      max_temp_time=datetime.datetime(2024, 10, 26, 12, 24, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=45,
#      min_temp_time=datetime.datetime(2024, 10, 26, 6, 57, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=52,
#      valid_time=datetime.datetime(2024, 10, 26, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 10, 26, 17, 46, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 10, 26),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=67,
#      max_temp_time=datetime.datetime(2024, 10, 26, 13, 3, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=51,
#      min_temp_time=datetime.datetime(2024, 10, 26, 2, 27, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=59,
#      valid_time=datetime.datetime(2024, 10, 26, 17, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 10, 27, 1, 45, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 10, 26),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=67,
#      max_temp_time=datetime.datetime(2024, 10, 26, 13, 3, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=50,
#      min_temp_time=datetime.datetime(2024, 10, 26, 23, 59, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=59,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 27, 1, 30, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 26),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=59,
#      max_temp_time=datetime.datetime(2024, 10, 26, 12, 24, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=45,
#      min_temp_time=datetime.datetime(2024, 10, 26, 22, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=52,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 27, 3, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 26),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=64,
#      max_temp_time=datetime.datetime(2024, 10, 26, 13, 47, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=51,
#      min_temp_time=datetime.datetime(2024, 10, 26, 23, 59, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=58,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.HOU: 'HOU'>,
#      issuance_time=datetime.datetime(2024, 10, 27, 2, 16, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='HGX',
#      summary_date=datetime.date(2024, 10, 26),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=90,
#      max_temp_time=datetime.datetime(2024, 10, 26, 14, 22, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=69,
#      min_temp_time=datetime.datetime(2024, 10, 26, 23, 59, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=80,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 27, 4, 21, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 26),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=86,
#      max_temp_time=datetime.datetime(2024, 10, 26, 12, 30, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=74,
#      min_temp_time=datetime.datetime(2024, 10, 26, 7, 2, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=80,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 27, 16, 22, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 27),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=83,
#      max_temp_time=datetime.datetime(2024, 10, 27, 12, 9, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=74,
#      min_temp_time=datetime.datetime(2024, 10, 27, 7, 14, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=79,
#      valid_time=datetime.datetime(2024, 10, 27, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 27, 16, 35, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 27),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=57,
#      max_temp_time=datetime.datetime(2024, 10, 27, 14, 59, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=45,
#      min_temp_time=datetime.datetime(2024, 10, 27, 7, 12, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=51,
#      valid_time=datetime.datetime(2024, 10, 27, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.HOU: 'HOU'>,
#      issuance_time=datetime.datetime(2024, 10, 27, 16, 33, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='HGX',
#      summary_date=datetime.date(2024, 10, 27),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=88,
#      max_temp_time=datetime.datetime(2024, 10, 27, 14, 20, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=66,
#      min_temp_time=datetime.datetime(2024, 10, 27, 6, 25, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=77,
#      valid_time=datetime.datetime(2024, 10, 27, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 27, 16, 34, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 27),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=59,
#      max_temp_time=datetime.datetime(2024, 10, 27, 14, 59, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=40,
#      min_temp_time=datetime.datetime(2024, 10, 27, 7, 1, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=50,
#      valid_time=datetime.datetime(2024, 10, 27, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 10, 27, 17, 35, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 10, 27),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=59,
#      max_temp_time=datetime.datetime(2024, 10, 27, 15, 33, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=43,
#      min_temp_time=datetime.datetime(2024, 10, 27, 7, 2, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=51,
#      valid_time=datetime.datetime(2024, 10, 27, 17, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 10, 28, 1, 49, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 10, 27),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=59,
#      max_temp_time=datetime.datetime(2024, 10, 27, 15, 33, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=43,
#      min_temp_time=datetime.datetime(2024, 10, 27, 7, 2, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=51,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 28, 2, 16, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 27),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=57,
#      max_temp_time=datetime.datetime(2024, 10, 27, 15, 36, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=45,
#      min_temp_time=datetime.datetime(2024, 10, 27, 7, 12, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=51,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 28, 1, 34, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 27),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=59,
#      max_temp_time=datetime.datetime(2024, 10, 27, 15, 43, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=40,
#      min_temp_time=datetime.datetime(2024, 10, 27, 7, 1, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=50,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.HOU: 'HOU'>,
#      issuance_time=datetime.datetime(2024, 10, 28, 2, 35, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='HGX',
#      summary_date=datetime.date(2024, 10, 27),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=88,
#      max_temp_time=datetime.datetime(2024, 10, 27, 14, 20, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=66,
#      min_temp_time=datetime.datetime(2024, 10, 27, 6, 25, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=77,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 28, 4, 21, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 27),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=83,
#      max_temp_time=datetime.datetime(2024, 10, 27, 12, 9, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=74,
#      min_temp_time=datetime.datetime(2024, 10, 27, 7, 14, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=79,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 28, 16, 21, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 28),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=83,
#      max_temp_time=datetime.datetime(2024, 10, 28, 12, 32, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=74,
#      min_temp_time=datetime.datetime(2024, 10, 28, 2, 43, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=79,
#      valid_time=datetime.datetime(2024, 10, 28, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 28, 16, 33, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 28),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=61,
#      max_temp_time=datetime.datetime(2024, 10, 28, 13, 22, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=46,
#      min_temp_time=datetime.datetime(2024, 10, 28, 4, 5, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=54,
#      valid_time=datetime.datetime(2024, 10, 28, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 28, 16, 34, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 28),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=67,
#      max_temp_time=datetime.datetime(2024, 10, 28, 14, 59, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=45,
#      min_temp_time=datetime.datetime(2024, 10, 28, 6, 44, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=56,
#      valid_time=datetime.datetime(2024, 10, 28, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.HOU: 'HOU'>,
#      issuance_time=datetime.datetime(2024, 10, 28, 16, 38, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='HGX',
#      summary_date=datetime.date(2024, 10, 28),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=88,
#      max_temp_time=datetime.datetime(2024, 10, 28, 13, 51, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=68,
#      min_temp_time=datetime.datetime(2024, 10, 28, 4, 14, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=78,
#      valid_time=datetime.datetime(2024, 10, 28, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 10, 28, 17, 40, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 10, 28),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=66,
#      max_temp_time=datetime.datetime(2024, 10, 28, 15, 49, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=40,
#      min_temp_time=datetime.datetime(2024, 10, 28, 3, 54, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=53,
#      valid_time=datetime.datetime(2024, 10, 28, 17, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 10, 29, 1, 44, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 10, 28),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=66,
#      max_temp_time=datetime.datetime(2024, 10, 28, 15, 49, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=40,
#      min_temp_time=datetime.datetime(2024, 10, 28, 3, 54, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=53,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 29, 2, 18, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 28),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=61,
#      max_temp_time=datetime.datetime(2024, 10, 28, 13, 22, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=46,
#      min_temp_time=datetime.datetime(2024, 10, 28, 4, 5, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=54,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.HOU: 'HOU'>,
#      issuance_time=datetime.datetime(2024, 10, 29, 1, 23, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='HGX',
#      summary_date=datetime.date(2024, 10, 28),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=88,
#      max_temp_time=datetime.datetime(2024, 10, 28, 13, 51, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=68,
#      min_temp_time=datetime.datetime(2024, 10, 28, 4, 14, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=78,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 29, 2, 40, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 28),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=68,
#      max_temp_time=datetime.datetime(2024, 10, 28, 23, 59, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=45,
#      min_temp_time=datetime.datetime(2024, 10, 28, 6, 44, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=57,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 29, 4, 21, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 28),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=83,
#      max_temp_time=datetime.datetime(2024, 10, 28, 12, 32, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=74,
#      min_temp_time=datetime.datetime(2024, 10, 28, 2, 43, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=79,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 29, 16, 23, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 29),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=85,
#      max_temp_time=datetime.datetime(2024, 10, 29, 14, 55, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=77,
#      min_temp_time=datetime.datetime(2024, 10, 29, 2, 12, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=81,
#      valid_time=datetime.datetime(2024, 10, 29, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 29, 16, 43, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 29),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=63,
#      max_temp_time=datetime.datetime(2024, 10, 29, 14, 49, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=52,
#      min_temp_time=datetime.datetime(2024, 10, 29, 1, 53, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=58,
#      valid_time=datetime.datetime(2024, 10, 29, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.HOU: 'HOU'>,
#      issuance_time=datetime.datetime(2024, 10, 29, 16, 11, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='HGX',
#      summary_date=datetime.date(2024, 10, 29),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=88,
#      max_temp_time=datetime.datetime(2024, 10, 29, 14, 3, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=72,
#      min_temp_time=datetime.datetime(2024, 10, 29, 6, 36, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=80,
#      valid_time=datetime.datetime(2024, 10, 29, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 10, 29, 17, 31, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 10, 29),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=69,
#      max_temp_time=datetime.datetime(2024, 10, 29, 15, 23, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=42,
#      min_temp_time=datetime.datetime(2024, 10, 29, 5, 36, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=56,
#      valid_time=datetime.datetime(2024, 10, 29, 17, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 29, 16, 33, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 29),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=83,
#      max_temp_time=datetime.datetime(2024, 10, 29, 14, 59, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=68,
#      min_temp_time=datetime.datetime(2024, 10, 29, 6, 24, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=76,
#      valid_time=datetime.datetime(2024, 10, 29, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 10, 30, 1, 47, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 10, 29),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=69,
#      max_temp_time=datetime.datetime(2024, 10, 29, 15, 23, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=42,
#      min_temp_time=datetime.datetime(2024, 10, 29, 5, 36, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=56,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 30, 2, 18, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 29),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=63,
#      max_temp_time=datetime.datetime(2024, 10, 29, 15, 25, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=52,
#      min_temp_time=datetime.datetime(2024, 10, 29, 1, 53, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=58,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.HOU: 'HOU'>,
#      issuance_time=datetime.datetime(2024, 10, 30, 1, 27, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='HGX',
#      summary_date=datetime.date(2024, 10, 29),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=88,
#      max_temp_time=datetime.datetime(2024, 10, 29, 14, 3, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=72,
#      min_temp_time=datetime.datetime(2024, 10, 29, 6, 36, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=80,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 30, 2, 41, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 29),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=83,
#      max_temp_time=datetime.datetime(2024, 10, 29, 15, 24, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=68,
#      min_temp_time=datetime.datetime(2024, 10, 29, 6, 24, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=76,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 30, 4, 26, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 29),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=85,
#      max_temp_time=datetime.datetime(2024, 10, 29, 14, 55, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=77,
#      min_temp_time=datetime.datetime(2024, 10, 29, 2, 12, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=81,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 10, 30, 16, 26, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 10, 30),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=86,
#      max_temp_time=datetime.datetime(2024, 10, 30, 13, 39, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=78,
#      min_temp_time=datetime.datetime(2024, 10, 30, 3, 58, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=82,
#      valid_time=datetime.datetime(2024, 10, 30, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 10, 30, 16, 39, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 10, 30),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=76,
#      max_temp_time=datetime.datetime(2024, 10, 30, 14, 47, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=58,
#      min_temp_time=datetime.datetime(2024, 10, 30, 6, 57, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=67,
#      valid_time=datetime.datetime(2024, 10, 30, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 10, 30, 17, 23, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 10, 30),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=76,
#      max_temp_time=datetime.datetime(2024, 10, 30, 15, 43, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      min_temp=53,
#      min_temp_time=datetime.datetime(2024, 10, 30, 6, 52, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      avg_temp=65,
#      valid_time=datetime.datetime(2024, 10, 30, 17, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 10, 30, 16, 34, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 10, 30),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=81,
#      max_temp_time=datetime.datetime(2024, 10, 30, 14, 25, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=69,
#      min_temp_time=datetime.datetime(2024, 10, 30, 6, 45, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=75,
#      valid_time=datetime.datetime(2024, 10, 30, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.HOU: 'HOU'>,
#      issuance_time=datetime.datetime(2024, 10, 30, 16, 42, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      issuing_office='HGX',
#      summary_date=datetime.date(2024, 10, 30),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=86,
#      max_temp_time=datetime.datetime(2024, 10, 30, 11, 43, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      min_temp=75,
#      min_temp_time=datetime.datetime(2024, 10, 30, 4, 52, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      avg_temp=81,
#      valid_time=datetime.datetime(2024, 10, 30, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CDT-1 day, 19:00:00 DST>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 10, 31, 1, 58, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 10, 30),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=76,
#      max_temp_time=datetime.datetime(2024, 10, 30, 16, 22, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>),
# ...
#      avg_temp=54,
#      valid_time=datetime.datetime(2024, 11, 17, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      is_correction=False),
#  CLI(station=<StationID.AUS: 'AUS'>,
#      issuance_time=datetime.datetime(2024, 11, 17, 16, 49, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      issuing_office='EWX',
#      summary_date=datetime.date(2024, 11, 17),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=86,
#      max_temp_time=datetime.datetime(2024, 11, 17, 15, 48, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      min_temp=59,
#      min_temp_time=datetime.datetime(2024, 11, 17, 1, 40, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      avg_temp=73,
#      valid_time=datetime.datetime(2024, 11, 17, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      is_correction=False),
#  CLI(station=<StationID.DEN: 'DEN'>,
#      issuance_time=datetime.datetime(2024, 11, 17, 16, 29, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      issuing_office='BOU',
#      summary_date=datetime.date(2024, 11, 17),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=54,
#      max_temp_time=datetime.datetime(2024, 11, 17, 13, 23, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      min_temp=26,
#      min_temp_time=datetime.datetime(2024, 11, 17, 7, 15, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      avg_temp=40,
#      valid_time=datetime.datetime(2024, 11, 17, 16, 0, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      is_correction=False),
#  CLI(station=<StationID.AUS: 'AUS'>,
#      issuance_time=datetime.datetime(2024, 11, 17, 17, 45, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      issuing_office='EWX',
#      summary_date=datetime.date(2024, 11, 17),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=86,
#      max_temp_time=datetime.datetime(2024, 11, 17, 15, 48, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      min_temp=59,
#      min_temp_time=datetime.datetime(2024, 11, 17, 1, 40, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      avg_temp=73,
#      valid_time=datetime.datetime(2024, 11, 17, 17, 0, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 11, 18, 0, 57, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 11, 17),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=61,
#      max_temp_time=datetime.datetime(2024, 11, 17, 15, 24, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      min_temp=41,
#      min_temp_time=datetime.datetime(2024, 11, 17, 5, 9, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      avg_temp=51,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.NYC: 'NYC'>,
#      issuance_time=datetime.datetime(2024, 11, 18, 1, 17, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      issuing_office='OKX',
#      summary_date=datetime.date(2024, 11, 17),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=63,
#      max_temp_time=datetime.datetime(2024, 11, 17, 13, 46, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      min_temp=44,
#      min_temp_time=datetime.datetime(2024, 11, 17, 7, 10, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      avg_temp=54,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MDW: 'MDW'>,
#      issuance_time=datetime.datetime(2024, 11, 18, 0, 34, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      issuing_office='LOT',
#      summary_date=datetime.date(2024, 11, 17),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=60,
#      max_temp_time=datetime.datetime(2024, 11, 17, 15, 21, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      min_temp=47,
#      min_temp_time=datetime.datetime(2024, 11, 17, 2, 18, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      avg_temp=54,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.HOU: 'HOU'>,
#      issuance_time=datetime.datetime(2024, 11, 18, 0, 35, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      issuing_office='HGX',
#      summary_date=datetime.date(2024, 11, 17),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=83,
#      max_temp_time=datetime.datetime(2024, 11, 17, 14, 9, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      min_temp=74,
#      min_temp_time=datetime.datetime(2024, 11, 17, 1, 18, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      avg_temp=79,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.DEN: 'DEN'>,
#      issuance_time=datetime.datetime(2024, 11, 18, 0, 33, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      issuing_office='BOU',
#      summary_date=datetime.date(2024, 11, 17),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=54,
#      max_temp_time=datetime.datetime(2024, 11, 17, 13, 23, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      min_temp=26,
#      min_temp_time=datetime.datetime(2024, 11, 17, 7, 15, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      avg_temp=40,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.AUS: 'AUS'>,
#      issuance_time=datetime.datetime(2024, 11, 18, 2, 5, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      issuing_office='EWX',
#      summary_date=datetime.date(2024, 11, 17),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=86,
#      max_temp_time=datetime.datetime(2024, 11, 17, 15, 48, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      min_temp=59,
#      min_temp_time=datetime.datetime(2024, 11, 17, 1, 40, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      avg_temp=73,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.MIA: 'MIA'>,
#      issuance_time=datetime.datetime(2024, 11, 18, 4, 21, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      issuing_office='MFL',
#      summary_date=datetime.date(2024, 11, 17),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=81,
#      max_temp_time=datetime.datetime(2024, 11, 17, 13, 19, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      min_temp=74,
#      min_temp_time=datetime.datetime(2024, 11, 17, 4, 36, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      avg_temp=78,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.DEN: 'DEN'>,
#      issuance_time=datetime.datetime(2024, 11, 18, 6, 28, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      issuing_office='BOU',
#      summary_date=datetime.date(2024, 11, 18),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=34,
#      max_temp_time=datetime.datetime(2024, 11, 18, 0, 11, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      min_temp=27,
#      min_temp_time=datetime.datetime(2024, 11, 18, 0, 22, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      avg_temp=31,
#      valid_time=datetime.datetime(2024, 11, 18, 6, 0, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      is_correction=False),
#  CLI(station=<StationID.AUS: 'AUS'>,
#      issuance_time=datetime.datetime(2024, 11, 18, 7, 49, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      issuing_office='EWX',
#      summary_date=datetime.date(2024, 11, 18),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=75,
#      max_temp_time=datetime.datetime(2024, 11, 18, 0, 33, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      min_temp=73,
#      min_temp_time=datetime.datetime(2024, 11, 18, 7, 0, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      avg_temp=74,
#      valid_time=datetime.datetime(2024, 11, 18, 7, 0, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      is_correction=False),
#  CLI(station=<StationID.DEN: 'DEN'>,
#      issuance_time=datetime.datetime(2024, 11, 18, 7, 26, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      issuing_office='BOU',
#      summary_date=datetime.date(2024, 11, 18),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=34,
#      max_temp_time=datetime.datetime(2024, 11, 18, 0, 11, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      min_temp=27,
#      min_temp_time=datetime.datetime(2024, 11, 18, 0, 22, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      avg_temp=31,
#      valid_time=datetime.datetime(2024, 11, 18, 6, 0, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 11, 18, 16, 35, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 11, 18),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=66,
#      max_temp_time=datetime.datetime(2024, 11, 18, 14, 39, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      min_temp=45,
#      min_temp_time=datetime.datetime(2024, 11, 18, 4, 1, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      avg_temp=56,
#      valid_time=datetime.datetime(2024, 11, 18, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      is_correction=False),
#  CLI(station=<StationID.HOU: 'HOU'>,
#      issuance_time=datetime.datetime(2024, 11, 18, 16, 19, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      issuing_office='HGX',
#      summary_date=datetime.date(2024, 11, 18),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=84,
#      max_temp_time=datetime.datetime(2024, 11, 18, 13, 12, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      min_temp=74,
#      min_temp_time=datetime.datetime(2024, 11, 18, 3, 7, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      avg_temp=79,
#      valid_time=datetime.datetime(2024, 11, 18, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      is_correction=False),
#  CLI(station=<StationID.DEN: 'DEN'>,
#      issuance_time=datetime.datetime(2024, 11, 18, 16, 30, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      issuing_office='BOU',
#      summary_date=datetime.date(2024, 11, 18),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=59,
#      max_temp_time=datetime.datetime(2024, 11, 18, 13, 12, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      min_temp=27,
#      min_temp_time=datetime.datetime(2024, 11, 18, 0, 22, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      avg_temp=43,
#      valid_time=datetime.datetime(2024, 11, 18, 16, 0, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 11, 19, 0, 48, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 11, 18),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=66,
#      max_temp_time=datetime.datetime(2024, 11, 18, 14, 39, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      min_temp=45,
#      min_temp_time=datetime.datetime(2024, 11, 18, 4, 1, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      avg_temp=56,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.DEN: 'DEN'>,
#      issuance_time=datetime.datetime(2024, 11, 19, 0, 29, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      issuing_office='BOU',
#      summary_date=datetime.date(2024, 11, 18),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=59,
#      max_temp_time=datetime.datetime(2024, 11, 18, 13, 12, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      min_temp=27,
#      min_temp_time=datetime.datetime(2024, 11, 18, 23, 51, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      avg_temp=43,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.HOU: 'HOU'>,
#      issuance_time=datetime.datetime(2024, 11, 19, 1, 33, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      issuing_office='HGX',
#      summary_date=datetime.date(2024, 11, 18),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=84,
#      max_temp_time=datetime.datetime(2024, 11, 18, 13, 12, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      min_temp=63,
#      min_temp_time=datetime.datetime(2024, 11, 18, 23, 41, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      avg_temp=74,
#      valid_time=None,
#      is_correction=False),
#  CLI(station=<StationID.DEN: 'DEN'>,
#      issuance_time=datetime.datetime(2024, 11, 19, 6, 28, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      issuing_office='BOU',
#      summary_date=datetime.date(2024, 11, 19),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=34,
#      max_temp_time=datetime.datetime(2024, 11, 19, 4, 9, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      min_temp=27,
#      min_temp_time=datetime.datetime(2024, 11, 19, 1, 27, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      avg_temp=31,
#      valid_time=datetime.datetime(2024, 11, 19, 6, 0, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      is_correction=False),
#  CLI(station=<StationID.DEN: 'DEN'>,
#      issuance_time=datetime.datetime(2024, 11, 19, 7, 28, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      issuing_office='BOU',
#      summary_date=datetime.date(2024, 11, 19),
#      raw_text='...',
#      is_afternoon_report=False,
#      max_temp=34,
#      max_temp_time=datetime.datetime(2024, 11, 19, 4, 9, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      min_temp=27,
#      min_temp_time=datetime.datetime(2024, 11, 19, 1, 27, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      avg_temp=31,
#      valid_time=datetime.datetime(2024, 11, 19, 6, 0, tzinfo=<DstTzInfo 'America/Denver' MST-1 day, 17:00:00 STD>),
#      is_correction=False),
#  CLI(station=<StationID.PHL: 'PHL'>,
#      issuance_time=datetime.datetime(2024, 11, 19, 16, 35, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      issuing_office='PHI',
#      summary_date=datetime.date(2024, 11, 19),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=60,
#      max_temp_time=datetime.datetime(2024, 11, 19, 15, 59, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      min_temp=46,
#      min_temp_time=datetime.datetime(2024, 11, 19, 6, 50, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      avg_temp=53,
#      valid_time=datetime.datetime(2024, 11, 19, 16, 0, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>),
#      is_correction=False),
#  CLI(station=<StationID.HOU: 'HOU'>,
#      issuance_time=datetime.datetime(2024, 11, 19, 16, 11, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      issuing_office='HGX',
#      summary_date=datetime.date(2024, 11, 19),
#      raw_text='...',
#      is_afternoon_report=True,
#      max_temp=81,
#      max_temp_time=datetime.datetime(2024, 11, 19, 15, 48, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      min_temp=57,
#      min_temp_time=datetime.datetime(2024, 11, 19, 7, 7, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      avg_temp=69,
#      valid_time=datetime.datetime(2024, 11, 19, 16, 0, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>),
#      is_correction=False)]

# %%
from dataclasses import asdict

# Turn the clis into a dateframe
df = pd.DataFrame([asdict(cli.without_raw_text()) for cli in clis])
df.set_index(['station', 'summary_date', 'issuance_time'], inplace=True)

df.head()
# Out:
#                                                issuing_office raw_text  \
# station summary_date issuance_time
# AUS     2024-11-03   2024-11-03 17:58:00-06:00            EWX      ...
#                      2024-11-04 02:18:00-06:00            EWX      ...
#         2024-11-04   2024-11-04 07:32:00-06:00            EWX      ...
#                      2024-11-04 16:36:00-06:00            EWX      ...
#                      2024-11-04 17:46:00-06:00            EWX      ...
#
#                                                 is_afternoon_report  max_temp  \
# station summary_date issuance_time
# AUS     2024-11-03   2024-11-03 17:58:00-06:00                 True      89.0
#                      2024-11-04 02:18:00-06:00                False      89.0
#         2024-11-04   2024-11-04 07:32:00-06:00                False      76.0
#                      2024-11-04 16:36:00-06:00                 True      88.0
#                      2024-11-04 17:46:00-06:00                 True      88.0
#
#                                                             max_temp_time  \
# station summary_date issuance_time
# AUS     2024-11-03   2024-11-03 17:58:00-06:00  2024-11-03 15:39:00-06:00
#                      2024-11-04 02:18:00-06:00  2024-11-03 15:39:00-06:00
#         2024-11-04   2024-11-04 07:32:00-06:00  2024-11-04 03:07:00-06:00
#                      2024-11-04 16:36:00-06:00  2024-11-04 15:17:00-06:00
#                      2024-11-04 17:46:00-06:00  2024-11-04 15:17:00-06:00
#
#                                                 min_temp  \
# station summary_date issuance_time
# AUS     2024-11-03   2024-11-03 17:58:00-06:00        73
#                      2024-11-04 02:18:00-06:00        73
#         2024-11-04   2024-11-04 07:32:00-06:00        75
#                      2024-11-04 16:36:00-06:00        75
#                      2024-11-04 17:46:00-06:00        75
#
#                                                             min_temp_time  \
# station summary_date issuance_time
# AUS     2024-11-03   2024-11-03 17:58:00-06:00  2024-11-03 06:29:00-06:00
#                      2024-11-04 02:18:00-06:00  2024-11-03 06:29:00-06:00
#         2024-11-04   2024-11-04 07:32:00-06:00  2024-11-04 05:59:00-06:00
#                      2024-11-04 16:36:00-06:00  2024-11-04 07:47:00-06:00
#                      2024-11-04 17:46:00-06:00  2024-11-04 07:47:00-06:00
#
#                                                 avg_temp  \
# station summary_date issuance_time
# AUS     2024-11-03   2024-11-03 17:58:00-06:00      81.0
#                      2024-11-04 02:18:00-06:00      81.0
#         2024-11-04   2024-11-04 07:32:00-06:00      76.0
#                      2024-11-04 16:36:00-06:00      82.0
#                      2024-11-04 17:46:00-06:00      82.0
#
#                                                                valid_time  \
# station summary_date issuance_time
# AUS     2024-11-03   2024-11-03 17:58:00-06:00  2024-11-03 17:00:00-06:00
#                      2024-11-04 02:18:00-06:00                       None
#         2024-11-04   2024-11-04 07:32:00-06:00  2024-11-04 07:00:00-06:00
#                      2024-11-04 16:36:00-06:00  2024-11-04 16:00:00-06:00
#                      2024-11-04 17:46:00-06:00  2024-11-04 17:00:00-06:00
#
#                                                 is_correction
# station summary_date issuance_time
# AUS     2024-11-03   2024-11-03 17:58:00-06:00          False
#                      2024-11-04 02:18:00-06:00          False
#         2024-11-04   2024-11-04 07:32:00-06:00          False
#                      2024-11-04 16:36:00-06:00          False
#                      2024-11-04 17:46:00-06:00          False

# %%
def gby_func(x, op: str = 'max'):
    x = x.reset_index()
    if op == 'max':
        x = x[x['issuance_time'] == x['issuance_time'].max()]
    elif op == 'min':
        x = x[x['issuance_time'] == x['issuance_time'].min()]
    return x

# Do filters
corrected_df = df[df["is_correction"]]
afternoon_df = df[df["is_afternoon_report"]]
end_of_day = df.groupby(['station', 'summary_date'])
end_of_day = end_of_day.apply(lambda x: gby_func(x, 'max'))
end_of_day = end_of_day.reset_index(drop=True)
end_of_day = end_of_day.set_index(['station', 'summary_date'])

first_afternoon = afternoon_df.groupby(['station', 'summary_date'])
first_afternoon = first_afternoon.apply(lambda x: gby_func(x, 'min'))
first_afternoon = first_afternoon.reset_index(drop=True)
first_afternoon = first_afternoon.set_index(['station', 'summary_date'])

# %%
display(end_of_day.head())
display(first_afternoon.head())
# Out:
#                                   issuance_time issuing_office raw_text  \
# station summary_date
# AUS     2024-11-03    2024-11-04 02:18:00-06:00            EWX      ...
#         2024-11-04    2024-11-05 02:18:00-06:00            EWX      ...
#         2024-11-05    2024-11-06 02:37:00-06:00            EWX      ...
#         2024-11-06    2024-11-07 03:12:00-06:00            EWX      ...
#         2024-11-07    2024-11-08 03:10:00-06:00            EWX      ...
#
#                       is_afternoon_report  max_temp  \
# station summary_date
# AUS     2024-11-03                  False      89.0
#         2024-11-04                  False      88.0
#         2024-11-05                  False      74.0
#         2024-11-06                  False      81.0
#         2024-11-07                  False      89.0
#
#                                   max_temp_time  min_temp  \
# station summary_date
# AUS     2024-11-03    2024-11-03 15:39:00-06:00        73
#         2024-11-04    2024-11-04 15:17:00-06:00        62
#         2024-11-05    2024-11-05 16:14:00-06:00        49
#         2024-11-06    2024-11-06 16:19:00-06:00        43
#         2024-11-07    2024-11-07 15:24:00-06:00        69
#
#                                   min_temp_time  avg_temp valid_time  \
# station summary_date
# AUS     2024-11-03    2024-11-03 06:29:00-06:00      81.0       None
#         2024-11-04    2024-11-04 23:59:00-06:00      75.0       None
#         2024-11-05    2024-11-05 23:40:00-06:00      62.0       None
#         2024-11-06    2024-11-06 06:33:00-06:00      62.0       None
#         2024-11-07    2024-11-07 06:44:00-06:00      79.0       None
#
#                       is_correction
# station summary_date
# AUS     2024-11-03            False
#         2024-11-04            False
#         2024-11-05            False
#         2024-11-06            False
#         2024-11-07            False
#                                   issuance_time issuing_office raw_text  \
# station summary_date
# AUS     2024-11-03    2024-11-03 17:58:00-06:00            EWX      ...
#         2024-11-04    2024-11-04 16:36:00-06:00            EWX      ...
#         2024-11-05    2024-11-05 16:49:00-06:00            EWX      ...
#         2024-11-06    2024-11-06 16:35:00-06:00            EWX      ...
#         2024-11-07    2024-11-07 17:19:00-06:00            EWX      ...
#
#                       is_afternoon_report  max_temp  \
# station summary_date
# AUS     2024-11-03                   True      89.0
#         2024-11-04                   True      88.0
#         2024-11-05                   True      74.0
#         2024-11-06                   True      81.0
#         2024-11-07                   True      89.0
#
#                                   max_temp_time  min_temp  \
# station summary_date
# AUS     2024-11-03    2024-11-03 15:39:00-06:00        73
#         2024-11-04    2024-11-04 15:17:00-06:00        75
#         2024-11-05    2024-11-05 15:57:00-06:00        61
#         2024-11-06    2024-11-06 15:59:00-06:00        43
#         2024-11-07    2024-11-07 15:24:00-06:00        69
#
#                                   min_temp_time  avg_temp  \
# station summary_date
# AUS     2024-11-03    2024-11-03 06:29:00-06:00      81.0
#         2024-11-04    2024-11-04 07:47:00-06:00      82.0
#         2024-11-05    2024-11-05 05:25:00-06:00      68.0
#         2024-11-06    2024-11-06 06:33:00-06:00      62.0
#         2024-11-07    2024-11-07 06:44:00-06:00      79.0
#
#                                      valid_time  is_correction
# station summary_date
# AUS     2024-11-03    2024-11-03 17:00:00-06:00          False
#         2024-11-04    2024-11-04 16:00:00-06:00          False
#         2024-11-05    2024-11-05 16:00:00-06:00          False
#         2024-11-06    2024-11-06 16:00:00-06:00          False
#         2024-11-07    2024-11-07 17:00:00-06:00          False

# %%
# Does end of day temp differ from the afternoon temp?
difference: pd.Series = end_of_day['max_temp'] - first_afternoon['max_temp']
difference.value_counts()
# Out:
# max_temp
# 0.0    149
# 1.0      5
# 4.0      1
# 3.0      1
# Name: count, dtype: int64

# %%
# print(f"Number of Corrected CLIs: {len(corrected_df)} -- Number of stations: {len(stations)}")
# for i, cli in corrected_clis:
#     prev_cli = clis[i-1]
#     if prev_cli.station == cli.station and prev_cli.summary_date == cli.summary_date:
#         print(f"Corrected CLI:\n{cli.raw_text}\n\n")
#         print(f"Previous CLI: \n{prev_cli.raw_text}\n\n")
# Out:
# Number of Corrected CLIs: 2 -- Number of stations: 7
# Corrected CLI:
# 419
# CDUS41 KOKX 090652 CCA
# CLINYC
#
# CLIMATE REPORT...CORRECTED
# NATIONAL WEATHER SERVICE NEW YORK, NY
# 152 AM EST SAT NOV 09 2024
#
# ...................................
#
# ...THE CENTRAL PARK NY CLIMATE SUMMARY FOR NOVEMBER 8 2024...
#
# CLIMATE NORMAL PERIOD 1991 TO 2020
# CLIMATE RECORD PERIOD 1869 TO 2024
#
#
# WEATHER ITEM   OBSERVED TIME   RECORD YEAR NORMAL DEPARTURE LAST
#                 VALUE   (LST)  VALUE       VALUE  FROM      YEAR
#                                                   NORMAL
# ...................................................................
# TEMPERATURE (F)
#  YESTERDAY
#   MAXIMUM         69    230 PM  76    1975  57     12       54
#   MINIMUM         50    643 AM  29    1886  44      6       43
#                                       2019
#   AVERAGE         60                        50     10       49
#
# PRECIPITATION (IN)
#   YESTERDAY        0.00          7.40 1977   0.12  -0.12     0.00
#   MONTH TO DATE    T                         0.94  -0.94     0.07
#   SINCE SEP 1      1.59                      9.63  -8.04    18.22
#   SINCE JAN 1     38.49                     42.50  -4.01    49.70
#
# SNOWFALL (IN)
#   YESTERDAY        0.0           0.4  2012   0.0    0.0      0.0
#   MONTH TO DATE    0.0                       0.1   -0.1      0.0
#   SINCE SEP 1      0.0                       0.2   -0.2      0.0
#   SINCE JUL 1      0.0                       0.2   -0.2      0.0
#   SNOW DEPTH       0
#
# DEGREE DAYS
#  HEATING
#   YESTERDAY        5                        15    -10       16
#   MONTH TO DATE   49                       110    -61      116
#   SINCE SEP 1    207                       382   -175      333
#   SINCE JUL 1    207                       383   -176      333
#
#  COOLING
#   YESTERDAY        0                         0      0        0
#   MONTH TO DATE   10                         0     10        0
#   SINCE SEP 1    168                       181    -13      224
#   SINCE JAN 1   1368                      1221    147     1242
# ...................................................................
#
#
# WIND (MPH)
#   HIGHEST WIND SPEED    20   HIGHEST WIND DIRECTION    NW (300)
#   HIGHEST GUST SPEED    37   HIGHEST GUST DIRECTION    NW (310)
#   AVERAGE WIND SPEED     5.4
#
#
# SKY COVER
#   AVERAGE SKY COVER 0.1
#
#
# WEATHER CONDITIONS
# THE FOLLOWING WEATHER WAS RECORDED YESTERDAY.
#   NO SIGNIFICANT WEATHER WAS OBSERVED.
#
#
# RELATIVE HUMIDITY (PERCENT)
#  HIGHEST    63           700 AM
#  LOWEST     21           300 PM
#  AVERAGE    42
#
# ..........................................................
#
#
# THE CENTRAL PARK NY CLIMATE NORMALS FOR TODAY
#                          NORMAL    RECORD    YEAR
#  MAXIMUM TEMPERATURE (F)   56        75      1975
#                                              2020
#  MINIMUM TEMPERATURE (F)   44        24      1976
#
#
# SUNRISE AND SUNSET
# NOVEMBER  9 2024......SUNRISE   636 AM EST   SUNSET   443 PM EST
# NOVEMBER 10 2024......SUNRISE   638 AM EST   SUNSET   442 PM EST
#
#
# -  INDICATES NEGATIVE NUMBERS.
# R  INDICATES RECORD WAS SET OR TIED.
# MM INDICATES DATA IS MISSING.
# T  INDICATES TRACE AMOUNT.
#
#
#
#
# $$
#
#
# Previous CLI:
# 571
# CDUS41 KOKX 090624
# CLINYC
#
# CLIMATE REPORT
# NATIONAL WEATHER SERVICE NEW YORK, NY
# 124 AM EST SAT NOV 09 2024
#
# ...................................
#
# ...THE CENTRAL PARK NY CLIMATE SUMMARY FOR NOVEMBER 8 2024...
#
# CLIMATE NORMAL PERIOD 1991 TO 2020
# CLIMATE RECORD PERIOD 1869 TO 2024
#
#
# WEATHER ITEM   OBSERVED TIME   RECORD YEAR NORMAL DEPARTURE LAST
#                 VALUE   (LST)  VALUE       VALUE  FROM      YEAR
#                                                   NORMAL
# ...................................................................
# TEMPERATURE (F)
#  YESTERDAY
#   MAXIMUM         69    230 PM  76    1975  57     12       54
#   MINIMUM         50    643 AM  29    1886  44      6       43
#                                       2019
#   AVERAGE         60                        50     10       49
#
# PRECIPITATION (IN)
#   YESTERDAY        0.00          7.40 1977   0.12  -0.12     0.00
#   MONTH TO DATE    0.00                      0.94  -0.94     0.07
#   SINCE SEP 1      1.59                      9.63  -8.04    18.22
#   SINCE JAN 1     38.49                     42.50  -4.01    49.70
#
# SNOWFALL (IN)
#   YESTERDAY        0.0           0.4  1991   0.0    0.0      0.0
#                                       2012
#   MONTH TO DATE    0.0                       0.1   -0.1      0.0
#   SINCE SEP 1      0.0                       0.2   -0.2      0.0
#   SINCE JUL 1      0.0                       0.2   -0.2      0.0
#   SNOW DEPTH       0
#
# DEGREE DAYS
#  HEATING
#   YESTERDAY        5                        15    -10       16
#   MONTH TO DATE   49                       110    -61      116
#   SINCE SEP 1    207                       382   -175      333
#   SINCE JUL 1    207                       383   -176      333
#
#  COOLING
#   YESTERDAY        0                         0      0        0
#   MONTH TO DATE   10                         0     10        0
#   SINCE SEP 1    168                       181    -13      224
#   SINCE JAN 1   1368                      1221    147     1242
# ...................................................................
#
#
# WIND (MPH)
#   HIGHEST WIND SPEED    20   HIGHEST WIND DIRECTION    NW (300)
#   HIGHEST GUST SPEED    37   HIGHEST GUST DIRECTION    NW (310)
#   AVERAGE WIND SPEED     5.4
#
#
# SKY COVER
#   AVERAGE SKY COVER 0.1
#
#
# WEATHER CONDITIONS
# THE FOLLOWING WEATHER WAS RECORDED YESTERDAY.
#   NO SIGNIFICANT WEATHER WAS OBSERVED.
#
#
# RELATIVE HUMIDITY (PERCENT)
#  HIGHEST    63           700 AM
#  LOWEST     21           300 PM
#  AVERAGE    42
#
# ..........................................................
#
#
# THE CENTRAL PARK NY CLIMATE NORMALS FOR TODAY
#                          NORMAL    RECORD    YEAR
#  MAXIMUM TEMPERATURE (F)   56        75      1975
#                                              2020
#  MINIMUM TEMPERATURE (F)   44        24      1976
#
#
# SUNRISE AND SUNSET
# NOVEMBER  9 2024......SUNRISE   636 AM EST   SUNSET   443 PM EST
# NOVEMBER 10 2024......SUNRISE   638 AM EST   SUNSET   442 PM EST
#
#
# -  INDICATES NEGATIVE NUMBERS.
# R  INDICATES RECORD WAS SET OR TIED.
# MM INDICATES DATA IS MISSING.
# T  INDICATES TRACE AMOUNT.
#
#
#
#
# $$
#
#
# Corrected CLI:
# 044
# CDUS41 KOKX 100642 CCA
# CLINYC
#
# CLIMATE REPORT...CORRECTED
# NATIONAL WEATHER SERVICE NEW YORK, NY
# 141 AM EST SUN NOV 10 2024
#
# ...................................
#
# ...THE CENTRAL PARK NY CLIMATE SUMMARY FOR NOVEMBER 9 2024...
#
# CLIMATE NORMAL PERIOD 1991 TO 2020
# CLIMATE RECORD PERIOD 1869 TO 2024
#
#
# WEATHER ITEM   OBSERVED TIME   RECORD YEAR NORMAL DEPARTURE LAST
#                 VALUE   (LST)  VALUE       VALUE  FROM      YEAR
#                                                   NORMAL
# ...................................................................
# TEMPERATURE (F)
#  YESTERDAY
#   MAXIMUM         54    353 PM  75    1975  56     -2       57
#                                       2020
#   MINIMUM         43    813 AM  24    1976  44     -1       42
#   AVERAGE         49                        50     -1       50
#
# PRECIPITATION (IN)
#   YESTERDAY        0.00          3.65 1889   0.12  -0.12     0.00
#   MONTH TO DATE    T                         1.06  -1.06     0.07
#   SINCE SEP 1      1.59                      9.75  -8.16    18.22
#   SINCE JAN 1     38.49                     42.62  -4.13    49.70
#
# SNOWFALL (IN)
#   YESTERDAY        0.0           2.3  1892   0.0    0.0      0.0
#   MONTH TO DATE    0.0                       0.1   -0.1      0.0
#   SINCE SEP 1      0.0                       0.2   -0.2      0.0
#   SINCE JUL 1      0.0                       0.2   -0.2      0.0
#   SNOW DEPTH       0
#
# DEGREE DAYS
#  HEATING
#   YESTERDAY       16                        15      1       15
#   MONTH TO DATE   65                       125    -60      131
#   SINCE SEP 1    223                       397   -174      348
#   SINCE JUL 1    223                       398   -175      348
#
#  COOLING
#   YESTERDAY        0                         0      0        0
#   MONTH TO DATE   10                         0     10        0
#   SINCE SEP 1    168                       181    -13      224
#   SINCE JAN 1   1368                      1221    147     1242
# ...................................................................
#
#
# WIND (MPH)
#   HIGHEST WIND SPEED    14   HIGHEST WIND DIRECTION    NW (300)
#   HIGHEST GUST SPEED    28   HIGHEST GUST DIRECTION     W (290)
#   AVERAGE WIND SPEED     4.2
#
#
# SKY COVER
#   AVERAGE SKY COVER 0.1
#
#
# WEATHER CONDITIONS
# THE FOLLOWING WEATHER WAS RECORDED YESTERDAY.
#   HAZE
#
#
# RELATIVE HUMIDITY (PERCENT)
#  HIGHEST    43           800 AM
#  LOWEST     21           200 PM
#  AVERAGE    32
#
# ..........................................................
#
#
# THE CENTRAL PARK NY CLIMATE NORMALS FOR TODAY
#                          NORMAL    RECORD    YEAR
#  MAXIMUM TEMPERATURE (F)   56        74      2020
#  MINIMUM TEMPERATURE (F)   44        25      2017
#
#
# SUNRISE AND SUNSET
# NOVEMBER 10 2024......SUNRISE   638 AM EST   SUNSET   442 PM EST
# NOVEMBER 11 2024......SUNRISE   639 AM EST   SUNSET   441 PM EST
#
#
# -  INDICATES NEGATIVE NUMBERS.
# R  INDICATES RECORD WAS SET OR TIED.
# MM INDICATES DATA IS MISSING.
# T  INDICATES TRACE AMOUNT.
#
#
#
#
# $$
#
#
# Previous CLI:
# 595
# CDUS41 KOKX 100631
# CLINYC
#
# CLIMATE REPORT
# NATIONAL WEATHER SERVICE NEW YORK, NY
# 131 AM EST SUN NOV 10 2024
#
# ...................................
#
# ...THE CENTRAL PARK NY CLIMATE SUMMARY FOR NOVEMBER 9 2024...
#
# CLIMATE NORMAL PERIOD 1991 TO 2020
# CLIMATE RECORD PERIOD 1869 TO 2024
#
#
# WEATHER ITEM   OBSERVED TIME   RECORD YEAR NORMAL DEPARTURE LAST
#                 VALUE   (LST)  VALUE       VALUE  FROM      YEAR
#                                                   NORMAL
# ...................................................................
# TEMPERATURE (F)
#  YESTERDAY
#   MAXIMUM         54    353 PM  75    1975  56     -2       57
#                                       2020
#   MINIMUM         43    813 AM  24    1976  44     -1       42
#   AVERAGE         49                        50     -1       50
#
# PRECIPITATION (IN)
#   YESTERDAY        0.00          3.65 1889   0.12  -0.12     0.00
#   MONTH TO DATE    0.00                      1.06  -1.06     0.07
#   SINCE SEP 1      1.59                      9.75  -8.16    18.22
#   SINCE JAN 1     38.49                     42.62  -4.13    49.70
#
# SNOWFALL (IN)
#   YESTERDAY        0.0           2.3  1892   0.0    0.0      0.0
#   MONTH TO DATE    0.0                       0.1   -0.1      0.0
#   SINCE SEP 1      0.0                       0.2   -0.2      0.0
#   SINCE JUL 1      0.0                       0.2   -0.2      0.0
#   SNOW DEPTH       0
#
# DEGREE DAYS
#  HEATING
#   YESTERDAY       16                        15      1       15
#   MONTH TO DATE   65                       125    -60      131
#   SINCE SEP 1    223                       397   -174      348
#   SINCE JUL 1    223                       398   -175      348
#
#  COOLING
#   YESTERDAY        0                         0      0        0
#   MONTH TO DATE   10                         0     10        0
#   SINCE SEP 1    168                       181    -13      224
#   SINCE JAN 1   1368                      1221    147     1242
# ...................................................................
#
#
# WIND (MPH)
#   HIGHEST WIND SPEED    14   HIGHEST WIND DIRECTION    NW (300)
#   HIGHEST GUST SPEED    28   HIGHEST GUST DIRECTION     W (290)
#   AVERAGE WIND SPEED     4.2
#
#
# SKY COVER
#   AVERAGE SKY COVER 0.1
#
#
# WEATHER CONDITIONS
# THE FOLLOWING WEATHER WAS RECORDED YESTERDAY.
#   HAZE
#
#
# RELATIVE HUMIDITY (PERCENT)
#  HIGHEST    43           800 AM
#  LOWEST     21           200 PM
#  AVERAGE    32
#
# ..........................................................
#
#
# THE CENTRAL PARK NY CLIMATE NORMALS FOR TODAY
#                          NORMAL    RECORD    YEAR
#  MAXIMUM TEMPERATURE (F)   56        74      2020
#  MINIMUM TEMPERATURE (F)   44        25      2017
#
#
# SUNRISE AND SUNSET
# NOVEMBER 10 2024......SUNRISE   638 AM EST   SUNSET   442 PM EST
# NOVEMBER 11 2024......SUNRISE   639 AM EST   SUNSET   441 PM EST
#
#
# -  INDICATES NEGATIVE NUMBERS.
# R  INDICATES RECORD WAS SET OR TIED.
# MM INDICATES DATA IS MISSING.
# T  INDICATES TRACE AMOUNT.
#
#
#
#
# $$

# %%
from datetime import time
from src.nws import CLI



# How many times is the afternoon report corrected?
total_temp_corrected_count = 0
total_corrected_count = 0
total_count = len([cli for cli in clis if is_afternoon_report(cli)])
for i, cli in corrected_clis:
    prev_cli = clis[i-1]
    if prev_cli.station == cli.station and prev_cli.summary_date == cli.summary_date:
        if is_afternoon_report(prev_cli):
            total_corrected_count += 1
            if cli.max_temp != prev_cli.max_temp:
                total_temp_corrected_count += 1

print(f"Total Corrected Count: {total_corrected_count} / {total_count}")
print(f"Total Temp Corrected Count: {total_temp_corrected_count} / {total_count}")
# Out:
# Total Corrected Count: 0 / 173
# Total Temp Corrected Count: 0 / 173

# %%
from collections import defaultdict

# How many times is the daily max temp different from the afternoon report
total_temp_diff_count = 0
afternoon_reports = [cli for cli in clis if is_afternoon_report(cli)]
# assert len(afternoon_reports) == set((cli.station, cli.summary_date) for cli in afternoon_reports)


# Did we overcount any summary dates?
afternoon_reports_by_station_summary_date = {k: [cli for cli in clis if is_afternoon_report(cli)] for k, clis in clis_by_station_summary_date.items()}
for k, clis in clis_by_station_summary_date.items():
    if len(afternoon_reports_by_station_summary_date[k]) > 1:
        print(f"Station: {k[0]} -- Summary Date: {k[1]} -- Afternoon Report Count: {len(afternoon_reports_by_station_summary_date[k])} -- Total Count: {len(clis)}")
        print(f"Afternoon Report Times: {[cli.issuance_time for cli in afternoon_reports_by_station_summary_date[k]]}")

# Get the daily report for the day
# Out:
# Station: AUS -- Summary Date: 2024-11-04 -- Afternoon Report Count: 2 -- Total Count: 4
# Afternoon Report Times: [datetime.datetime(2024, 11, 4, 16, 36, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 4, 17, 46, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: AUS -- Summary Date: 2024-11-05 -- Afternoon Report Count: 3 -- Total Count: 5
# Afternoon Report Times: [datetime.datetime(2024, 11, 5, 16, 49, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 5, 16, 53, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 5, 17, 41, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: AUS -- Summary Date: 2024-11-06 -- Afternoon Report Count: 2 -- Total Count: 4
# Afternoon Report Times: [datetime.datetime(2024, 11, 6, 16, 35, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 6, 17, 51, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: AUS -- Summary Date: 2024-11-07 -- Afternoon Report Count: 2 -- Total Count: 4
# Afternoon Report Times: [datetime.datetime(2024, 11, 7, 17, 19, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 7, 17, 59, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: AUS -- Summary Date: 2024-11-08 -- Afternoon Report Count: 2 -- Total Count: 4
# Afternoon Report Times: [datetime.datetime(2024, 11, 8, 16, 41, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 8, 17, 41, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: AUS -- Summary Date: 2024-11-09 -- Afternoon Report Count: 2 -- Total Count: 4
# Afternoon Report Times: [datetime.datetime(2024, 11, 9, 16, 37, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 9, 17, 34, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: AUS -- Summary Date: 2024-11-10 -- Afternoon Report Count: 2 -- Total Count: 4
# Afternoon Report Times: [datetime.datetime(2024, 11, 10, 16, 42, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 10, 17, 40, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: AUS -- Summary Date: 2024-11-11 -- Afternoon Report Count: 2 -- Total Count: 4
# Afternoon Report Times: [datetime.datetime(2024, 11, 11, 16, 27, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 11, 17, 32, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: AUS -- Summary Date: 2024-11-12 -- Afternoon Report Count: 2 -- Total Count: 4
# Afternoon Report Times: [datetime.datetime(2024, 11, 12, 16, 30, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 12, 17, 40, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: AUS -- Summary Date: 2024-11-13 -- Afternoon Report Count: 2 -- Total Count: 4
# Afternoon Report Times: [datetime.datetime(2024, 11, 13, 16, 45, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 13, 17, 45, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: AUS -- Summary Date: 2024-11-14 -- Afternoon Report Count: 2 -- Total Count: 4
# Afternoon Report Times: [datetime.datetime(2024, 11, 14, 16, 38, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 14, 17, 40, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: AUS -- Summary Date: 2024-11-15 -- Afternoon Report Count: 2 -- Total Count: 4
# Afternoon Report Times: [datetime.datetime(2024, 11, 15, 16, 33, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 15, 17, 39, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: AUS -- Summary Date: 2024-11-16 -- Afternoon Report Count: 2 -- Total Count: 4
# Afternoon Report Times: [datetime.datetime(2024, 11, 16, 16, 22, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 16, 17, 27, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: AUS -- Summary Date: 2024-11-17 -- Afternoon Report Count: 2 -- Total Count: 4
# Afternoon Report Times: [datetime.datetime(2024, 11, 17, 16, 49, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 17, 17, 45, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]
# Station: HOU -- Summary Date: 2024-11-11 -- Afternoon Report Count: 2 -- Total Count: 3
# Afternoon Report Times: [datetime.datetime(2024, 11, 11, 16, 8, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>), datetime.datetime(2024, 11, 11, 16, 15, tzinfo=<DstTzInfo 'America/Chicago' CST-1 day, 18:00:00 STD>)]

# %%
from dataclasses import asdict

# Make a dataframe that includes all the issuance times of all the clis
df = pd.DataFrame([asdict(cli.without_raw_text()) for cli in clis])
df.drop(columns=['raw_text'], inplace=True)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   issuance_time   55 non-null     datetime64[ns, America/Chicago]
#  1   issuing_office  55 non-null     object
#  2   summary_date    55 non-null     object
#  3   max_temp        55 non-null     int64
#  4   max_temp_time   54 non-null     datetime64[ns, America/Chicago]
#  5   min_temp        55 non-null     int64
#  6   min_temp_time   54 non-null     datetime64[ns, America/Chicago]
#  7   avg_temp        55 non-null     int64
#  8   valid_time      27 non-null     datetime64[ns, America/Chicago]
# dtypes: datetime64[ns, America/Chicago](4), int64(3), object(2)
# memory usage: 4.0+ KB
#               issuance_time issuing_office summary_date  max_temp  \
# 0 2024-10-22 01:33:00-05:00            LOT   2024-10-21        82
# 1 2024-10-22 16:36:00-05:00            LOT   2024-10-22        74
# 2 2024-10-23 01:34:00-05:00            LOT   2024-10-22        75
# 3 2024-10-23 16:36:00-05:00            LOT   2024-10-23        65
# 4 2024-10-24 01:37:00-05:00            LOT   2024-10-23        65
#
#               max_temp_time  min_temp             min_temp_time  avg_temp  \
# 0 2024-10-21 16:06:00-05:00        53 2024-10-21 04:07:00-05:00        68
# 1 2024-10-22 14:59:00-05:00        55 2024-10-22 06:18:00-05:00        65
# 2 2024-10-22 15:45:00-05:00        55 2024-10-22 06:18:00-05:00        65
# 3 2024-10-23 14:47:00-05:00        58 2024-10-23 06:37:00-05:00        62
# 4                       NaT        46                       NaT        56
#
#                  valid_time
# 0                       NaT
# 1 2024-10-22 16:00:00-05:00
# 2                       NaT
# 3 2024-10-23 16:00:00-05:00
# 4                       NaT

# %%
# Plot the ranges of the CLI timeframes
import plotly.express as px

issue_df = df[["issuance_time"]].copy()
issue_df["issuance_time"] = issue_df["issuance_time"].dt.time
# Filter on those that are between 4-5pm
hours = range(16, 18)
issue_df = issue_df[issue_df["issuance_time"].apply(lambda t: t.hour in hours)]
issue_df["issuance_time"] = issue_df["issuance_time"].apply(lambda t: ((t.hour - min(hours)) * 60 + t.minute))

binsize = 1 # minute
fig = px.histogram(issue_df, x="issuance_time", nbins=180//binsize)
fig.show()

# %%
# MIA Release times
# 16:21 to 16:40 Eastern
# NYC Release times
# 16:32 to 16:52 Eastern
# AUS Release times
# 16:22 - 17:59 Central
# MDW Release times
# 16:32 to 16:51 Central
